# %%
pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.9.2-py3-none-any.whl.metadata (13 kB)
# Collecting click<9,>=7.0 (from mlflow)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle<4 (from mlflow)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow)
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting entrypoints<1 (from mlflow)
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting gitpython<4,>=2.1.0 (from mlflow)
#   Downloading GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (6.0.1)
# Collecting protobuf<5,>=3.12.0 (from mlflow)
#   Downloading protobuf-4.25.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: pytz<2024 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (2023.3.post1)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: packaging<24 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (23.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (6.0.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow)
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 552.6 kB/s eta 0:00:00 0:00:01
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.13.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<7,>=4.0.0 (from mlflow)
#   Downloading docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.0.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy<2 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (1.24.4)
# Requirement already satisfied: scipy<2 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (1.10.1)
# Requirement already satisfied: pandas<3 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (2.0.3)
# Collecting querystring-parser<2 (from mlflow)
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading SQLAlchemy-2.0.23-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: scikit-learn<2 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (1.3.2)
# Collecting pyarrow<15,>=4.0.0 (from mlflow)
#   Downloading pyarrow-14.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting markdown<4,>=3.3 (from mlflow)
#   Downloading Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: matplotlib<4 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (3.7.2)
# Collecting gunicorn<22 (from mlflow)
#   Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from mlflow) (3.1.2)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading Mako-1.3.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from alembic!=1.10.0,<2->mlflow) (4.7.1)
# Requirement already satisfied: importlib-resources in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from alembic!=1.10.0,<2->mlflow) (6.1.0)
# Collecting pyjwt>=1.7.0 (from databricks-cli<1,>=0.8.7->mlflow)
#   Downloading PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting oauthlib>=3.1.0 (from databricks-cli<1,>=0.8.7->mlflow)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting tabulate>=0.7.7 (from databricks-cli<1,>=0.8.7->mlflow)
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: six>=1.10.0 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.26.18)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from docker<7,>=4.0.0->mlflow) (0.58.0)
# Collecting Werkzeug>=3.0.0 (from Flask<4->mlflow)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting itsdangerous>=2.1.2 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting blinker>=1.6.2 (from Flask<4->mlflow)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=2.1.0->mlflow)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=0.5 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from matplotlib<4->mlflow) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from matplotlib<4->mlflow) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from requests<3,>=2.17.3->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from requests<3,>=2.17.3->mlflow) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from scikit-learn<2->mlflow) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tiger/miniconda3/envs/mle-dev/lib/python3.8/site-packages (from scikit-learn<2->mlflow) (3.2.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Downloading greenlet-3.0.2-cp38-cp38-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading mlflow-2.9.2-py3-none-any.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 11.1 MB/s eta 0:00:0000:0100:01
# Downloading alembic-1.13.0-py3-none-any.whl (230 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.6/230.6 kB 7.2 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 6.5 MB/s eta 0:00:00
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 8.1 MB/s eta 0:00:00
# Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 11.3 MB/s eta 0:00:00
# Downloading flask-3.0.0-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 9.1 MB/s eta 0:00:00
# Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 12.2 MB/s eta 0:00:00
# Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 6.8 MB/s eta 0:00:00
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 8.0 MB/s eta 0:00:00
# Downloading protobuf-4.25.1-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 13.9 MB/s eta 0:00:00
# Downloading pyarrow-14.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 9.0 MB/s eta 0:00:0000:0100:01m
# Downloading SQLAlchemy-2.0.23-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 33.5 MB/s eta 0:00:00a 0:00:01
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.8 MB/s eta 0:00:00
# Downloading greenlet-3.0.2-cp38-cp38-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (618 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 23.9 MB/s eta 0:00:00
# Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 19.4 MB/s eta 0:00:00
# Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.2 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: Werkzeug, tabulate, sqlparse, smmap, querystring-parser, pyjwt, pyarrow, protobuf, oauthlib, Mako, itsdangerous, gunicorn, greenlet, entrypoints, cloudpickle, click, blinker, sqlalchemy, markdown, gitdb, Flask, docker, databricks-cli, gitpython, alembic, mlflow
# Successfully installed Flask-3.0.0 Mako-1.3.0 Werkzeug-3.0.1 alembic-1.13.0 blinker-1.7.0 click-8.1.7 cloudpickle-3.0.0 databricks-cli-0.18.0 docker-6.1.3 entrypoints-0.4 gitdb-4.0.11 gitpython-3.1.40 greenlet-3.0.2 gunicorn-21.2.0 itsdangerous-2.1.2 markdown-3.5.1 mlflow-2.9.2 oauthlib-3.2.2 protobuf-4.25.1 pyarrow-14.0.1 pyjwt-2.8.0 querystring-parser-1.2.4 smmap-5.0.1 sqlalchemy-2.0.23 sqlparse-0.4.4 tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import warnings
import sys

import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet

import mlflow
import mlflow.sklearn

# %%
data_path = "data/wine-quality.csv"
data = pd.read_csv(data_path)

data.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4182            7.5              0.38         0.56             9.7      0.055
# 733             6.6              0.25         0.30            14.4      0.052
# 171             7.9              0.19         0.45             1.5      0.045
# 4525            5.8              0.13         0.22            12.7      0.058
# 4775            5.0              0.27         0.40             1.2      0.076
# 3062            6.8              0.28         0.43             7.6      0.030
# 2954            6.4              0.29         0.30             2.9      0.036
# 1588            7.3              0.30         0.74            13.5      0.039
# 984             6.9              0.19         0.33             1.6      0.043
# 3407            6.1              0.33         0.32             7.8      0.052
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4182                 15.0                 170.0  0.99605  3.13       0.65
# 733                  40.0                 183.0  0.99800  3.02       0.50
# 171                  17.0                  96.0  0.99170  3.13       0.39
# 4525                 24.0                 183.0  0.99560  3.32       0.42
# 4775                 42.0                 124.0  0.99204  3.32       0.47
# 3062                 30.0                 110.0  0.99164  3.08       0.59
# 2954                 25.0                  79.0  0.99037  3.29       0.60
# 1588                 46.0                 165.0  0.99820  3.02       0.40
# 984                  63.0                 149.0  0.99250  3.44       0.52
# 3407                 52.0                 183.0  0.99657  3.39       0.65
#
#       alcohol  quality
# 4182      9.9        6
# 733       9.1        6
# 171      11.0        6
# 4525     11.7        6
# 4775     10.1        6
# 3062     12.5        8
# 2954     12.4        7
# 1588      8.7        5
# 984      10.8        5
# 3407      9.5        5

# %%
# mlflow server --backend-store-uri mlruns/ --default-artifact-root mlruns/ --host 0.0.0.0 --port 5000
remote_server_uri = "http://0.0.0.0:5000" # set to your server URI
mlflow.set_tracking_uri(remote_server_uri)  # or set the MLFLOW_TRACKING_URI in the env

# %%
mlflow.tracking.get_tracking_uri()
# Out:
# 'http://0.0.0.0:5000'

# %%
exp_name = "ElasticNet_wine"
mlflow.set_experiment(exp_name)
# Out:
# 2023/12/18 11:10:00 INFO mlflow.tracking.fluent: Experiment with name 'ElasticNet_wine' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/722937459539626797', creation_time=1702878000160, experiment_id='722937459539626797', last_update_time=1702878000160, lifecycle_stage='active', name='ElasticNet_wine', tags={}>

# %%
def eval_metrics(actual, pred):
    # compute relevant metrics
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2


def load_data(data_path):
    data = pd.read_csv(data_path)

    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)

    # The predicted column is "quality" which is a scalar from [3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]
    return train_x, train_y, test_x, test_y


def train(alpha=0.5, l1_ratio=0.5):
    # train a model with given parameters
    warnings.filterwarnings("ignore")
    np.random.seed(40)

    # Read the wine-quality csv file (make sure you're running this from the root of MLflow!)
    data_path = "data/wine-quality.csv"
    train_x, train_y, test_x, test_y = load_data(data_path)

    # Useful for multiple runs (only doing one run in this sample notebook)    
    with mlflow.start_run():
        # Execute ElasticNet
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        # Evaluate Metrics
        predicted_qualities = lr.predict(test_x)
        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

        # Print out metrics
        print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, l1_ratio))
        print("  RMSE: %s" % rmse)
        print("  MAE: %s" % mae)
        print("  R2: %s" % r2)

        # Log parameter, metrics, and model to MLflow
        mlflow.log_param(key="alpha", value=alpha)
        mlflow.log_param(key="l1_ratio", value=l1_ratio)
        mlflow.log_metric(key="rmse", value=rmse)
        mlflow.log_metrics({"mae": mae, "r2": r2})
        mlflow.log_artifact(data_path)
        print("Save to: {}".format(mlflow.get_artifact_uri()))
        
        mlflow.sklearn.log_model(lr, "model")

# %%
train(0.5, 0.5)
# Out:
# Elasticnet model (alpha=0.500000, l1_ratio=0.500000):
#   RMSE: 0.8222428497595401
#   MAE: 0.6278761410160693
#   R2: 0.12678721972772666
# Save to: mlflow-artifacts:/722937459539626797/bcc74edaa14744ef90f77a9990a9f612/artifacts
# 2023/12/18 11:10:51 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpjbc4sdtr/model/model.pkl, flavor: sklearn), fall back to return ['scikit-learn==1.3.0', 'cloudpickle==3.0.0']. Set logging level to DEBUG to see the full traceback.

# %%
train(0.2, 0.2)
# Out:
# 2023/12/18 11:11:00 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmp5_a8uc95/model/model.pkl, flavor: sklearn), fall back to return ['scikit-learn==1.3.0', 'cloudpickle==3.0.0']. Set logging level to DEBUG to see the full traceback.
# Elasticnet model (alpha=0.200000, l1_ratio=0.200000):
#   RMSE: 0.7859129997062342
#   MAE: 0.6155290394093894
#   R2: 0.20224631822892092
# Save to: mlflow-artifacts:/722937459539626797/3967fabc093541db824b40d283a57158/artifacts

# %%
train(0.1, 0.1)
# Out:
# 2023/12/18 11:11:06 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpya6o_hia/model/model.pkl, flavor: sklearn), fall back to return ['scikit-learn==1.3.0', 'cloudpickle==3.0.0']. Set logging level to DEBUG to see the full traceback.
# Elasticnet model (alpha=0.100000, l1_ratio=0.100000):
#   RMSE: 0.7792546522251949
#   MAE: 0.6112547988118586
#   R2: 0.2157063843066196
# Save to: mlflow-artifacts:/722937459539626797/87b8288041da4b10bc5675c3c65a59c7/artifacts
